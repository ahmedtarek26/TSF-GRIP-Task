# %% [markdown]
# ## TSF GRIP  **Task#5**
# ##  **Author :** Ahmed Tarek Elsayed
#
# + Dataset: https://bit.ly/34SRn3b

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ## Loading matches dataset

# %%
matches = pd.read_csv("/content/drive/MyDrive/Intern/Spark_Intern/Indian Premier League.zip (Unzipped Files)/matches.csv")
matches.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
matches.tail()
# Out:
#         id  season  ...         umpire2                  umpire3
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...             NaN                      NaN
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...       Ian Gould              Nigel Llong
#
# [5 rows x 18 columns]

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
#  17  umpire3          119 non-null    object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %% [markdown]
# ## Loading deliveries dataset

# %%
deliveries = pd.read_csv("/content/drive/MyDrive/Intern/Spark_Intern/Indian Premier League.zip (Unzipped Files)/deliveries.csv")
deliveries.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
deliveries.tail()
# Out:
#         match_id  inning  ... dismissal_kind    fielder
# 179073     11415       2  ...            NaN        NaN
# 179074     11415       2  ...            NaN        NaN
# 179075     11415       2  ...        run out  KH Pandya
# 179076     11415       2  ...            NaN        NaN
# 179077     11415       2  ...            lbw        NaN
#
# [5 rows x 21 columns]

# %%
deliveries.describe()
# Out:
#             match_id         inning  ...     extra_runs     total_runs
# count  179078.000000  179078.000000  ...  179078.000000  179078.000000
# mean     1802.252957       1.482952  ...       0.067032       1.313897
# std      3472.322805       0.502074  ...       0.342553       1.605422
# min         1.000000       1.000000  ...       0.000000       0.000000
# 25%       190.000000       1.000000  ...       0.000000       0.000000
# 50%       379.000000       1.000000  ...       0.000000       1.000000
# 75%       567.000000       2.000000  ...       0.000000       1.000000
# max     11415.000000       5.000000  ...       7.000000      10.000000
#
# [8 rows x 13 columns]

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
#  16  extra_runs        179078 non-null  int64
#  17  total_runs        179078 non-null  int64
#  18  player_dismissed  8834 non-null    object
#  19  dismissal_kind    8834 non-null    object
#  20  fielder           6448 non-null    object
# dtypes: int64(13), object(8)
# memory usage: 28.7+ MB

# %% [markdown]
# ## Merging datasets

# %%
df = pd.merge(deliveries,matches, left_on='match_id', right_on ='id')
df.head()
# Out:
#    match_id  inning         batting_team  ...      umpire1   umpire2  umpire3
# 0         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
# 1         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
# 2         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
# 3         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
# 4         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
#
# [5 rows x 39 columns]

# %%
df.tail()
# Out:
#         match_id  inning  ...    umpire2      umpire3
# 179073     11415       2  ...  Ian Gould  Nigel Llong
# 179074     11415       2  ...  Ian Gould  Nigel Llong
# 179075     11415       2  ...  Ian Gould  Nigel Llong
# 179076     11415       2  ...  Ian Gould  Nigel Llong
# 179077     11415       2  ...  Ian Gould  Nigel Llong
#
# [5 rows x 39 columns]

# %%
df.describe()
# Out:
#             match_id         inning  ...    win_by_runs  win_by_wickets
# count  179078.000000  179078.000000  ...  179078.000000   179078.000000
# mean     1802.252957       1.482952  ...      13.404036        3.261579
# std      3472.322805       0.502074  ...      23.261007        3.347033
# min         1.000000       1.000000  ...       0.000000        0.000000
# 25%       190.000000       1.000000  ...       0.000000        0.000000
# 50%       379.000000       1.000000  ...       0.000000        3.000000
# 75%       567.000000       2.000000  ...      19.000000        6.000000
# max     11415.000000       5.000000  ...     146.000000       10.000000
#
# [8 rows x 18 columns]

# %% [markdown]
#  ## Data Preprocessing

# %%
matches.set_index('id', inplace=True)

# %%
matches.describe()
# Out:
#             season  dl_applied  win_by_runs  win_by_wickets
# count   756.000000  756.000000   756.000000      756.000000
# mean   2013.444444    0.025132    13.283069        3.350529
# std       3.366895    0.156630    23.471144        3.387963
# min    2008.000000    0.000000     0.000000        0.000000
# 25%    2011.000000    0.000000     0.000000        0.000000
# 50%    2013.000000    0.000000     0.000000        4.000000
# 75%    2016.000000    0.000000    19.000000        6.000000
# max    2019.000000    1.000000   146.000000       10.000000

# %%
matches.describe(include='all')
# Out:
#              season    city  ...        umpire2      umpire3
# count    756.000000     749  ...            754          119
# unique          NaN      32  ...             65           25
# top             NaN  Mumbai  ...  C Shamshuddin  Nitin Menon
# freq            NaN     101  ...             57           10
# mean    2013.444444     NaN  ...            NaN          NaN
# std        3.366895     NaN  ...            NaN          NaN
# min     2008.000000     NaN  ...            NaN          NaN
# 25%     2011.000000     NaN  ...            NaN          NaN
# 50%     2013.000000     NaN  ...            NaN          NaN
# 75%     2016.000000     NaN  ...            NaN          NaN
# max     2019.000000     NaN  ...            NaN          NaN
#
# [11 rows x 17 columns]

# %%
matches.head()
# Out:
#     season       city        date  ...         umpire1        umpire2 umpire3
# id                                 ...
# 1     2017  Hyderabad  2017-04-05  ...     AY Dandekar       NJ Llong     NaN
# 2     2017       Pune  2017-04-06  ...  A Nand Kishore         S Ravi     NaN
# 3     2017     Rajkot  2017-04-07  ...     Nitin Menon      CK Nandan     NaN
# 4     2017     Indore  2017-04-08  ...    AK Chaudhary  C Shamshuddin     NaN
# 5     2017  Bangalore  2017-04-08  ...             NaN            NaN     NaN
#
# [5 rows x 17 columns]

# %%
matches.isnull().sum()
# Out:
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# city , winner , player_of_match , umpire1 ,umpire2 , umpire3 have null values 🤕🤕

# %%
matches['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
matches[matches.city.isnull()][['city','venue']]
# Out:
#     city                                venue
# id
# 462  NaN  Dubai International Cricket Stadium
# 463  NaN  Dubai International Cricket Stadium
# 467  NaN  Dubai International Cricket Stadium
# 469  NaN  Dubai International Cricket Stadium
# 470  NaN  Dubai International Cricket Stadium
# 475  NaN  Dubai International Cricket Stadium
# 477  NaN  Dubai International Cricket Stadium

# %%
# fill nan data
matches.city = matches.city.fillna('Dubai')

# %%
matches.loc[matches['city']=='Dubai']
# Out:
#      season   city        date  ...          umpire1         umpire2 umpire3
# id                              ...
# 462    2014  Dubai  2014-04-19  ...        Aleem Dar    AK Chaudhary     NaN
# 463    2014  Dubai  2014-04-19  ...        Aleem Dar     VA Kulkarni     NaN
# 467    2014  Dubai  2014-04-23  ...  HDPK Dharmasena  RK Illingworth     NaN
# 469    2014  Dubai  2014-04-25  ...        M Erasmus          S Ravi     NaN
# 470    2014  Dubai  2014-04-25  ...        BF Bowden       M Erasmus     NaN
# 475    2014  Dubai  2014-04-28  ...        BF Bowden          S Ravi     NaN
# 477    2014  Dubai  2014-04-30  ...  HDPK Dharmasena       M Erasmus     NaN
#
# [7 rows x 17 columns]

# %%
matches[(matches.umpire1.isnull()) | (matches.umpire2.isnull())]
# Out:
# Empty DataFrame
# Columns: [season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
matches = matches.drop([5,11413], axis=0)

# %%
matches[matches.umpire3.isnull()]
# Out:
#        season           city  ...          umpire2 umpire3
# id                            ...
# 1        2017      Hyderabad  ...         NJ Llong     NaN
# 2        2017           Pune  ...           S Ravi     NaN
# 3        2017         Rajkot  ...        CK Nandan     NaN
# 4        2017         Indore  ...    C Shamshuddin     NaN
# 5        2017      Bangalore  ...              NaN     NaN
# ...       ...            ...  ...              ...     ...
# 633      2016      Bangalore  ...  HDPK Dharmasena     NaN
# 634      2016          Delhi  ...    C Shamshuddin     NaN
# 635      2016          Delhi  ...        CK Nandan     NaN
# 636      2016      Bangalore  ...     BNJ Oxenford     NaN
# 11413    2019  Visakhapatnam  ...              NaN     NaN
#
# [637 rows x 17 columns]

# %%
matches=matches.drop('umpire3',axis=1)

# %% [markdown]
# ## Exploratory Data Analysis:

# %%
fig=px.bar(matches,x='city',y='season',color='venue',title='Number of stadiums in different cities over seasons')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c7ebacb3-fa3c-4f74-babe-1926b00df1a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7ebacb3-fa3c-4f74-babe-1926b00df1a0")) {                    Plotly.newPlot(                        "c7ebacb3-fa3c-4f74-babe-1926b00df1a0",                        [{"alignmentgroup":"True","hovertemplate":"venue=Rajiv Gandhi International Stadium, Uppal<br>city=%{x}<br>season=%{y}<extra></extra>","legendgroup":"Rajiv Gandhi International Stadium, Uppal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rajiv Gandhi International Stadium, Uppal","offsetgroup":"Rajiv Gandhi International Stadium, Uppal","orientation":"v","showlegend":true,"textposition":"auto","x":["Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad"],"xaxis":"x","y":[2017,2017,2017,2017,2017,2017,2017,2017,2008,2008,2008,2008,2008,2008,2008,2011,2011,2011,2011,2011,2011,2011,2012,2012,2012,2012,2013,2013,2013,2013,2013,2013,2013,2013,2014,2014,2014,2014,2015,2015,2015,2015,2016,2016,2016,2016,2016,2016,2016,2018,2018,2018,2018,2018,2018,2018],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"venue=Maharashtra Cricket Association Stadium<br>city=%{x}<br>season=%{y}<extra></extra>","legendgroup":"Maharashtra Cricket Association Stadium","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Maharashtra Cricket Association Stadium","offsetgroup":"Maharashtra Cricket Association Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune"],"xaxis":"x","y":[2017,2017,2017,2017,2017,2017,2017,2015,2015,2015,2015,2016,2016,2016,2016,2018,2018,2018,2018,2018,2018],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"venue=Saurashtra Cricket Association Stadium<br>city=%{x}<br>season=%{y}<extra></extra>","legendgroup":"Saurashtra Cricket Association Stadium","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Saurashtra Cricket Association Stadium","offsetgroup":"Saurashtra Cricket Association Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["Rajkot","Rajkot","Rajkot","Rajkot","Rajkot","Rajkot","Rajkot","Rajkot","Rajkot","Rajkot"],"xaxis":"x","y":[2017,2017,2017,2017,2017,2016,2016,2016,2016,2016],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"venue=Holkar Cricket Stadium<br>city=%{x}<br>season=%{y}<extra></extra>","legendgroup":"Holkar Cricket Stadium","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Holkar Cricket Stadium","offsetgroup":"Holkar Cricket Stadium","orientation":"v","showlegend":true,"textposition":"auto","x":["Indore","Indore","Indore","Indore","Indore","Indore","Indore","Indore","Indore"],"xaxis":"x","y":[2017,2017,2017,2011,2011,2018,2018,2018,2018],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"venue=Wankhede Stadium<br>city=%{x}<br>season=%{y}<extra></extra>","legendgroup":"Wankhede Stadium","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Wankhede Stadium","offsetgroup":" ...

# %% [markdown]
# + Bengaluru and Bangalore both are in the data when they are same. So we need to keep one of them.
# + Chandigarh and Mohali are same and there is just one stadium Punjab Cricket Association IS Bindra Stadium, Mohali whose value has not been entered correctly. We need to have either Chandigarh or Mohali as well as correct name of the stadium there.
# + Mumbai has 3 stadiums/venues used for IPL
# + Pune has 2 venues for IPL

# %%
x=matches['season'].value_counts()
fig=px.bar(x,title='Number of matches played each season')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b731e3e8-0eb1-49a8-a846-fc9d62568b9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b731e3e8-0eb1-49a8-a846-fc9d62568b9f")) {                    Plotly.newPlot(                        "b731e3e8-0eb1-49a8-a846-fc9d62568b9f",                        [{"alignmentgroup":"True","hovertemplate":"variable=season<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"season","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"season","offsetgroup":"season","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2012,2011,2010,2014,2016,2018,2015,2019,2017,2008,2009],"xaxis":"x","y":[76,74,73,60,60,60,60,59,59,58,58,57],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlin ...

# %% [markdown]
# 2013 have most matches being played than other seasons

# %%
matches.groupby('season')['team1'].nunique().plot(kind = 'bar', figsize=(20,5))
plt.title("Number of teams participated each season ",fontsize=18,fontweight="bold")
plt.ylabel("Count of teams", size = 20)
plt.xlabel("Season", size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %% [markdown]
# + 10 teams played in 2011 and 9 teams each in 2012 and 2013
# + This explains why 2011-2013 have seen more matches being played than other seasons

# %%
matches.venue.value_counts().sort_values(ascending = True).tail(10).plot(kind = 'barh',figsize=(12,8), fontsize=15, color='green')
plt.title("Venue which has hosted most number of IPL matches",fontsize=18,fontweight="bold")
plt.ylabel("Venue", size = 25)
plt.xlabel("Frequency", size = 25)
plt.show()

# %%
fig=px.bar(matches,x='season',y='winner',color='season',title='Winners of IPL across 11 seasons')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="06e5a353-2fa2-4ba2-918e-57b356b3dd9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06e5a353-2fa2-4ba2-918e-57b356b3dd9b")) {                    Plotly.newPlot(                        "06e5a353-2fa2-4ba2-918e-57b356b3dd9b",                        [{"alignmentgroup":"True","hovertemplate":"season=%{marker.color}<br>winner=%{y}<extra></extra>","legendgroup":"","marker":{"color":[2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2 ...

# %% [markdown]
# MI and CSK have most wins.

# %%
matches['toss_decision'].value_counts().plot(kind='pie', fontsize=14, autopct='%3.1f%%', 
                                               figsize=(10,7), shadow=True, startangle=135, legend=True, cmap='Blues')

plt.ylabel('Toss Decision')
plt.title('Decision taken by captains after winning tosses')
plt.show()

# %% [markdown]
# Close to 60% times teams who have won tosses have decided to chase down

# %%
matches['toss_win_game_win'] = np.where((matches.toss_winner == matches.winner),'Yes','No')
plt.figure(figsize = (15,5))
sns.countplot('toss_win_game_win', data=matches, hue = 'toss_decision')
plt.title("How Toss Decision affects match result", fontsize=18,fontweight="bold")
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel("Winning Toss and winning match", fontsize = 20)
plt.ylabel("Frequency", fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Teams winning tosses and electng to field first have won most number of times.

# %%
plt.figure(figsize = (25,10))
sns.countplot('toss_winner', data = matches, hue = 'toss_decision')
plt.title("Teams decision to bat first or second after winning toss", size = 20, fontweight = 'bold')
plt.xticks(size = 15,rotation=45)
plt.yticks(size = 15)
plt.xlabel("Toss Winner", size = 20)
plt.ylabel("Count", size = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Most teams field first after winning toss except for Chennai Super Kings who has mostly opted to bat first. Deccan Chargers and Pune Warriors also show the same trend.

# %%
MoM= matches['player_of_match'].value_counts()[:10]
fig=px.bar(MoM)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ea45492f-8483-4d29-b013-c569ec96c521" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea45492f-8483-4d29-b013-c569ec96c521")) {                    Plotly.newPlot(                        "ea45492f-8483-4d29-b013-c569ec96c521",                        [{"alignmentgroup":"True","hovertemplate":"variable=player_of_match<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"player_of_match","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"player_of_match","offsetgroup":"player_of_match","orientation":"v","showlegend":true,"textposition":"auto","x":["CH Gayle","AB de Villiers","DA Warner","RG Sharma","MS Dhoni","YK Pathan","SR Watson","SK Raina","G Gambhir","V Kohli"],"xaxis":"x","y":[21,20,17,17,17,16,15,14,13,12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parco ...

# %% [markdown]
# + Chris Gayle has so far won the most number of MoM awards followed by AB de Villiers.
# + Also, all top 10 are batsmen which kind of hints that in IPL batsmen have mostly dictated the matches

# %%
new_matches = matches[matches['result'] == 'normal']   #taking all those matches where result is normal and creating a new dataframe
new_matches['win_batting_first'] = np.where((new_matches.win_by_runs > 0), 'Yes', 'No')
new_matches.groupby('venue')['win_batting_first'].value_counts().unstack().plot(kind = 'barh', stacked = True,
                                                                               figsize=(15,15))
plt.title("How winning matches by fielding first varies across venues?", fontsize=18,fontweight="bold")
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel("Frequency", fontsize = 25)
plt.ylabel("Venue", fontsize = 25)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Batting second has been more rewarding in almost all the venues

# %%
plt.figure(figsize = (15,5))
sns.countplot('season', data = new_matches, hue = 'win_batting_first')
plt.title("Is batting second advantageous across all years", fontsize=20,fontweight="bold")
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel("Season", fontsize = 20)
plt.ylabel("Count", fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Except for 2010 and 2015, in all other years it can be seen that teams batting second have won more matches

# %%
df.groupby('season')['batsman_runs'].sum().plot(kind = 'line', linewidth = 3, figsize =(15,5),
                                                                                             color = 'blue')
plt.title("Runs over the years",fontsize= 20, fontweight = 'bold')
plt.xlabel("Season", size = 20)
plt.ylabel("Total Runs Scored", size = 20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# Run scoring has gone up from the start of the IPL in 2008.

# %%
df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'orange',
                                                                                            figsize = (15,5))
plt.title("Top Run Getters of IPL", fontsize = 20, fontweight = 'bold')
plt.xlabel("Batsmen", size = 20)
plt.ylabel("Total Runs Scored", size = 20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# + Except for MS Dhoni, all other top run getters are either openers or come in 3rd or 4th positions to bat
# + Suresh Raina is the highest run getter in IPL.

# %%
consistent_batsman = df[df.batsman.isin(['SK Raina', 'V Kohli','RG Sharma','G Gambhir',
                                            'RV Uthappa', 'S Dhawan','CH Gayle', 'MS Dhoni',
                                            'DA Warner', 'AB de Villiers'])][['batsman','season','total_runs']]

consistent_batsman.groupby(['season','batsman'])['total_runs'].sum().unstack().plot(kind = 'box', figsize = (15,8))
plt.title("Most Consistent batsmen of IPL", fontsize = 20, fontweight = 'bold')
plt.xlabel("Batsmen", size = 20)
plt.ylabel("Total Runs Scored each season", size = 20)
plt.xticks(size = 15,rotation=50)
plt.yticks(size = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %% [markdown]
# Median score for Raina is above all the top 10 run getters. He has the highest lowest run among all the batsmen across 11 seasons. Considering the highest and lowest season totals and spread of runs, it seems Raina has been most consistent among all.

# %%
df.groupby('bowler')['player_dismissed'].count().sort_values(ascending = False).head(10).plot(kind = 'bar', 
                                                color = 'purple', figsize = (15,5))
plt.title("Top Wicket Takers of IPL", fontsize = 20, fontweight = 'bold')
plt.xlabel("Bowler", size = 20)
plt.ylabel("Total Wickets Taken", size = 20)
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.show()

# %% [markdown]
# + Malinga has taken the most number of wickets in IPL followed by Bravo and Amit Mishra
# + In top 10 bowlers, 5 are fast and medium pacers while the other 5 are spinners
# + All 5 spinners are right arm spinners and 2 are leg spinners while 3 are off spinners
# + All 5 pacers are right arm pacers

# %%
#We will consider players who have played 10 or more seasons
no_of_balls = pd.DataFrame(df.groupby('batsman')['ball'].count()) #total number of matches played by each batsman
runs = pd.DataFrame(df.groupby('batsman')['batsman_runs'].sum()) #total runs of each batsman
seasons = pd.DataFrame(df.groupby('batsman')['season'].nunique()) #season = 1 implies played only 1 season

batsman_strike_rate = pd.DataFrame({'balls':no_of_balls['ball'],'run':runs['batsman_runs'],'season':seasons['season']})
batsman_strike_rate.reset_index(inplace = True)

batsman_strike_rate['strike_rate'] = batsman_strike_rate['run']/batsman_strike_rate['balls']*100
highest_strike_rate = batsman_strike_rate[batsman_strike_rate.season.isin([10,11])][['season','batsman','strike_rate']].sort_values(by = 'strike_rate',
                                                                                                            ascending = False)
fig=px.bar(highest_strike_rate,x='batsman',y='strike_rate',color='season')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3c4a4c0c-1b93-4923-8a31-e1977ddf6fdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c4a4c0c-1b93-4923-8a31-e1977ddf6fdf")) {                    Plotly.newPlot(                        "3c4a4c0c-1b93-4923-8a31-e1977ddf6fdf",                        [{"alignmentgroup":"True","hovertemplate":"batsman=%{x}<br>strike_rate=%{y}<br>season=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[11,10,10,11,11,10,11,11,10,11,11,10,11,10,10,10,10,10,10,10,10],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CH Gayle","KA Pollard","DA Warner","SR Watson","BB McCullum","STR Binny","DJ Bravo","Yuvraj Singh","AT Rayudu","G Gambhir","AM Rahane","M Vijay","RA Jadeja","R Bhatia","NV Ojha","MK Tiwary","R Ashwin","R Vinay Kumar","P Kumar","UT Yadav","DS Kulkarni"],"xaxis":"x","y":[145.64037048866177,141.75152749490834,139.52324896998235,136.9458128078818,127.33274647887325,126.0,125.56580050293378,125.28318985047575,124.05818724356583,119.83541430192963,119.75116640746502,119.68576709796672,119.546568627451,117.9310344827586,114.33823529411764,113.96910678307589,109.14285714285714,107.61245674740485,105.26315789473684,95.48872180451127,90.990990990991],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dco ...

# %%
extra = deliveries[deliveries['extra_runs']!=0]['bowler'].value_counts()[:50]
px.bar(extra,title='Bowlers who have bowled maximum number of Extra balls')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="33974485-4f88-4370-8f30-82030464a024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33974485-4f88-4370-8f30-82030464a024")) {                    Plotly.newPlot(                        "33974485-4f88-4370-8f30-82030464a024",                        [{"alignmentgroup":"True","hovertemplate":"variable=bowler<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"bowler","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"bowler","offsetgroup":"bowler","orientation":"v","showlegend":true,"textposition":"auto","x":["SL Malinga","P Kumar","UT Yadav","DJ Bravo","B Kumar","SR Watson","I Sharma","RP Singh","DW Steyn","R Ashwin","Z Khan","Harbhajan Singh","JA Morkel","IK Pathan","DS Kulkarni","L Balaji","A Mishra","M Morkel","JJ Bumrah","MJ McClenaghan","R Vinay Kumar","A Nehra","JH Kallis","M Muralitharan","AB Dinda","KA Pollard","JP Faulkner","MG Johnson","VR Aaron","PP Ojha","SK Trivedi","S Sreesanth","RA Jadeja","SW Tait","Sandeep Sharma","YS Chahal","SP Narine","CH Morris","Mohammed Shami","B Lee","AR Patel","PJ Sangwan","PP Chawla","DP Nannes","TG Southee","HH Pandya","YK Pathan","RJ Harris","MM Sharma","AB Agarkar"],"xaxis":"x","y":[221,185,180,176,162,155,151,145,139,133,132,126,121,120,108,107,103,100,100,99,97,96,96,96,94,92,90,88,87,87,87,84,83,83,82,82,76,75,71,67,66,65,64,64,63,63,63,59,58,57],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...
